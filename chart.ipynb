# %%
import matplotlib.pyplot as plt

naive = [143239200, 177469300, 245602300, 246186300, 279485700, 318499900, 361598300, 413151900, 460026400, 507224700, 591919300, 614978500, 679510600, 801563700, 820376700, 890168800, 985603700, 1036690400, 1124974700, 1180799100, 1257913700]
kd_tree = [75800, 80400, 62100, 70100, 55400, 64600, 49100, 51800, 70500, 62900, 57900, 51400, 77900, 55300, 66100, 62300, 74300, 52300, 60400, 66200, 66100]

# %%
fig, ax = plt.subplots()
x = [(1000+n*100)*(1000+n*100) for n in range(21)]
plt.plot(x, naive, color = 'green')
plt.title("naive method")
plt.xlabel('$points(n^2)$')
plt.ylabel("time consumption (ns)")
plt.show()

# %%
fig, ax = plt.subplots()
x = [(1000+n*100)*(1000+n*100) for n in range(21)]
plt.plot(x, kd_tree)
plt.title("kd-tree")
plt.xlabel('$points(n^2)$')
plt.ylabel("time consumption (ns)")
plt.show()

# %%
fig, ax = plt.subplots()
x = [(1000+n*100)*(1000+n*100) for n in range(21)]
plt.plot(x, kd_tree, label = "kd-tree")
plt.plot(x, navie, label = "navie method")
plt.title("two method")
plt.xlabel('$points(n^2)$')
plt.ylabel("time consumption (ns)")
plt.show()
